# %%
import ast
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from typing import List
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

# %%
def load_all_csvs(csv_paths: List[str]) -> pd.DataFrame:
        """Load and combine multiple experiment CSVs."""
        dfs = []
        for path in csv_paths:
            df = pd.read_csv(path, index_col=0)
            df['source_file'] = Path(path).parent.name  # track which experiment it came from
            dfs.append(df)

            combined = pd.concat(dfs, ignore_index=True)
                
        return combined

# %%
paths = ['data/results/2428981015/ni_n_sweep/ni10n_10000_red3_1_sweep//results_sd2428981015.csv', 'data/results/2428981015/ni_n_sweep/ni10n_20000_red3_1_sweep//results_sd2428981015.csv', 'data/results/2428981015/ni_n_sweep/ni10n_40000_red3_1_sweep//results_sd2428981015.csv', 'data/results/2428981015/ni_n_sweep/ni10n_60000_red3_1_sweep//results_sd2428981015.csv']
df = load_all_csvs(paths)
df['gap_size_range_tuple'] = df['gap_size_range'].apply(ast.literal_eval)
df['reduce_triggerSz_sizeLim_tuple'] = df['reduce_triggerSz_sizeLim'].apply(ast.literal_eval)
df
# Out:
#     master_seed data_type  num_trials  dataset_size  uncertain_ratio  \
# 0    2428981015       set           5         10000              0.0
# 1    2428981015       set           5         10000              0.0
# 2    2428981015       set           5         10000              0.0
# 3    2428981015       set           5         10000              0.0
# 4    2428981015       set           5         10000              0.0
# ..          ...       ...         ...           ...              ...
# 35   2428981015       set           5         60000              0.0
# 36   2428981015       set           5         60000              0.0
# 37   2428981015       set           5         60000              0.0
# 38   2428981015       set           5         60000              0.0
# 39   2428981015       set           5         60000              0.0
#
#    interval_size_range mult_size_range  num_intervals  gap_size  \
# 0           (1, 10000)          (1, 5)              1       NaN
# 1           (1, 10000)          (1, 5)              2       NaN
# 2           (1, 10000)          (1, 5)              3       NaN
# 3           (1, 10000)          (1, 5)              4       NaN
# 4           (1, 10000)          (1, 5)              5       NaN
# ..                 ...             ...            ...       ...
# 35          (1, 10000)          (1, 5)              6       NaN
# 36          (1, 10000)          (1, 5)              7       NaN
# 37          (1, 10000)          (1, 5)              8       NaN
# 38          (1, 10000)          (1, 5)              9       NaN
# 39          (1, 10000)          (1, 5)             10       NaN
#
#     interval_width  num_intervals_range gap_size_range interval_width_range  \
# 0              NaN                  NaN   (9500, 9900)           (100, 500)
# 1              NaN                  NaN   (4750, 4950)           (100, 500)
# 2              NaN                  NaN   (3166, 3300)           (100, 500)
# 3              NaN                  NaN   (2375, 2475)           (100, 500)
# 4              NaN                  NaN   (1900, 1980)           (100, 500)
# ..             ...                  ...            ...                  ...
# 35             NaN                  NaN   (1583, 1650)           (100, 500)
# 36             NaN                  NaN   (1357, 1414)           (100, 500)
# 37             NaN                  NaN   (1187, 1237)           (100, 500)
# 38             NaN                  NaN   (1055, 1100)           (100, 500)
# 39             NaN                  NaN     (950, 990)           (100, 500)
#
#    reduce_triggerSz_sizeLim independent_variable  min_time_mean  min_time_std  \
# 0                    (3, 1)        num_intervals        10.5126      3.981482
# 1                    (3, 1)        num_intervals        11.0972      0.111113
# 2                    (3, 1)        num_intervals        13.0612      0.320306
# 3                    (3, 1)        num_intervals        14.6738      0.236081
# 4                    (3, 1)        num_intervals        16.3730      0.776936
# ..                      ...                  ...            ...           ...
# 35                   (3, 1)        num_intervals        99.1402      4.704317
# 36                   (3, 1)        num_intervals        98.3878      2.969898
# 37                   (3, 1)        num_intervals        97.7822      2.866011
# 38                   (3, 1)        num_intervals       100.2812      2.178266
# 39                   (3, 1)        num_intervals       105.8152      8.848038
#
#     max_time_mean  max_time_std  sum_time_mean  sum_time_std  \
# 0         11.6736      6.055518         6.0740      0.209081
# 1         11.1088      0.210170         7.5700      0.592862
# 2         13.1036      0.182017         8.1716      0.148554
# 3         15.0026      0.507159         9.2336      0.477665
# 4         16.7586      0.264999        10.7656      1.093377
# ..            ...           ...            ...           ...
# 35       110.5532      1.099224        63.8754      1.149440
# 36       120.4488      3.772533        67.9086      0.995435
# 37       134.4096     20.353072        73.4838      6.506360
# 38       141.0572      8.414633        74.3788      1.239493
# 39       137.4198      3.936058        78.1634      1.314083
#
#     sumtest_time_mean  sumtest_time_std  reduce_calls_mean  \
# 0             10.4864          5.622465                0.0
# 1              7.1304          0.158611             5000.0
# 2              8.0302          0.188483             9999.0
# 3              8.8472          0.223289             9999.0
# 4              9.5442          0.262233             9999.0
# ..                ...               ...                ...
# 35            60.4376          0.361644            59999.0
# 36            66.1188          1.687385            59999.0
# 37            67.6828          0.450746            59999.0
# 38            74.4216          1.667739            59999.0
# 39            76.8018          2.360249            59999.0
#
#     max_interval_count_mean  total_interval_count_mean  combine_calls_mean  \
# 0                       1.0                    10000.0             10000.0
# 1                       4.0                    30000.0             10000.0
# 2                       9.0                    30006.0             10000.0
# 3                      16.0                    40012.0             10000.0
# 4                      25.0                    50020.0             10000.0
# ..                      ...                        ...                 ...
# 35                     36.0                   356740.6             60000.0
# 36                     38.4                   381283.6             60000.0
# 37                     49.0                   421799.4             60000.0
# 38                     60.8                   472782.6             60000.0
# 39                     70.6                   499386.4             60000.0
#
#     result_size_mean  result_coverage_mean               source_file  \
# 0                1.0             3001906.6  ni10n_10000_red3_1_sweep
# 1                1.0            54490507.8  ni10n_10000_red3_1_sweep
# 2                1.0            73640593.6  ni10n_10000_red3_1_sweep
# 3                1.0            84734868.4  ni10n_10000_red3_1_sweep
# 4                1.0            92572134.4  ni10n_10000_red3_1_sweep
# ..               ...                   ...                       ...
# 35               1.0           586315134.2  ni10n_60000_red3_1_sweep
# 36               1.0           559146323.0  ni10n_60000_red3_1_sweep
# 37               1.0           564601863.8  ni10n_60000_red3_1_sweep
# 38               1.0           586119570.4  ni10n_60000_red3_1_sweep
# 39               1.0           575492649.8  ni10n_60000_red3_1_sweep
#
#    gap_size_range_tuple reduce_triggerSz_sizeLim_tuple
# 0          (9500, 9900)                         (3, 1)
# 1          (4750, 4950)                         (3, 1)
# 2          (3166, 3300)                         (3, 1)
# 3          (2375, 2475)                         (3, 1)
# 4          (1900, 1980)                         (3, 1)
# ..                  ...                            ...
# 35         (1583, 1650)                         (3, 1)
# 36         (1357, 1414)                         (3, 1)
# 37         (1187, 1237)                         (3, 1)
# 38         (1055, 1100)                         (3, 1)
# 39           (950, 990)                         (3, 1)
#
# [40 rows x 32 columns]

# %%
sizes = sorted(df_metrics['dataset_size'].unique())
df_metrics = df[['dataset_size', 'num_intervals', 'result_coverage_mean', 'sum_time_mean']]

fig, axes = plt.subplots(1, 2, figsize=(12,6), sharex=True)

for size in sizes:
    df_n = df_metrics[df_metrics['dataset_size'] == size].sort_values('num_intervals')
    
    axes[0].plot(df_n['num_intervals'], df_n['result_coverage_mean'], marker='o', label=f'n={size}')
    axes[1].plot(df_n['num_intervals'], df_n['sum_time_mean'], marker='o', label=f'n={size}')

axes[0].set_xlabel('ni')
axes[0].set_ylabel('cover')
axes[0].set_title('cover vs ni')
axes[0].grid(True)
axes[0].legend(title='dataset_size')

axes[1].set_xlabel('ni')
axes[1].set_ylabel('time (ms)')
axes[1].set_title('time (ms) vs ni')
axes[1].grid(True)
axes[1].legend(title='dataset_size')

plt.tight_layout()
plt.show()
